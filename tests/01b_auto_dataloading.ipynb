# %%
from nocode_robot_programming.state_decision_dataset_prepare.dataloader import TrajectoryDataset
import trajectory_data
loader = TrajectoryDataset(trajectory_data.package_path)

# %%
loader.plot_task_graph(skill_name="p0_probe")

# %%
from nocode_robot_programming.state_decision_dataset_prepare.dataset_auto import load_dataset
from nocode_robot_programming.state_decision.utils import Filename

# %%
datasets  = [load_dataset(loader, name) for name in list(loader.tasks.keys())]

# %%
[d_.showcase_aligned(scale=1.0)
    for d in datasets
    for d_ in d]

# %% [markdown]
# ## Conclusion
#
# - I can see dataset images aligned nicely
# -
#
# Notes:
# `p1b_peg_pick` - Long distance to the peg
